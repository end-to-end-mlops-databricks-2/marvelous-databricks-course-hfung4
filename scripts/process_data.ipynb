# %%
from airbnb_listing.data_processor import DataProcessor
import pandas as pd
from pathlib import Path

# %%
# Import the data
train = pd.read_csv(Path("..",'src','airbnb_listing','data','train.csv'))

# %%
train.head()
# Out:
#         id                                 name   host_id  host_name  \
# 0  9901706                 Cute big one bedroom   1904415    Natalie
# 1   299531  Feel like you never leave your home   1220404        Tom
# 2  2461439   Pristine Lower East Side Sanctuary  12586492     Sausan
# 3   127387     Luxe, Spacious 2BR 2BA Nr Trains     23276  Katharine
# 4   629315   1BD brownstone apt in Fort Greene!   2397437     Lauren
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan  Upper West Side  40.77789  -73.97701  Entire home/apt
# 1            Brooklyn    East New York  40.66795  -73.89232  Entire home/apt
# 2           Manhattan  Lower East Side  40.72007  -73.98946  Entire home/apt
# 3            Brooklyn          Gowanus  40.66862  -73.99260  Entire home/apt
# 4            Brooklyn      Fort Greene  40.68935  -73.96950  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
data_processor = DataProcessor(train)

# %%
processed_data = data_processor.preprocess()

# %%
processed_data.head()
# Out:
#         id  is_manhattan    neighbourhood        room_type  minimum_nights  \
# 0  9901706          True  Upper West Side  Entire home/apt               1
# 1   299531         False    East New York  Entire home/apt               1
# 2  2461439          True  Lower East Side  Entire home/apt              14
# 3   127387         False          Gowanus  Entire home/apt              14
# 4   629315         False      Fort Greene  Entire home/apt               3
#
#    latitude  longitude  days_since_last_review  estimated_listed_months  \
# 0  40.77789  -73.97701                     NaN                      NaN
# 1  40.66795  -73.89232                  2044.0                85.611511
# 2  40.72007  -73.98946                  2102.0                62.765957
# 3  40.66862  -73.99260                  3835.0               100.000000
# 4  40.68935  -73.96950                  3385.0                81.481481
#
#    availability_365  number_of_reviews  calculated_host_listings_count  \
# ...
